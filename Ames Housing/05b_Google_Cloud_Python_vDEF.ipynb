# %% [markdown]
# <h1>Anexo 5b. Google Cloud en Python<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Pasos-realizados-en-el-Cloud-de-Google" data-toc-modified-id="Pasos-realizados-en-el-Cloud-de-Google-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Pasos realizados en el Cloud de Google</a></span></li><li><span><a href="#Pantallazos-durante-la-ejecución-del-Notebook" data-toc-modified-id="Pantallazos-durante-la-ejecución-del-Notebook-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Pantallazos durante la ejecución del Notebook</a></span><ul class="toc-item"><li><span><a href="#Pantalla-con-la-ejecución-de-un-modelo" data-toc-modified-id="Pantalla-con-la-ejecución-de-un-modelo-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Pantalla con la ejecución de un modelo</a></span></li><li><span><a href="#Pantalla-final-tras-la-ejecución-completa-del-Notebook:" data-toc-modified-id="Pantalla-final-tras-la-ejecución-completa-del-Notebook:-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span><strong>Pantalla final tras la ejecución completa del Notebook:</strong></a></span></li></ul></li><li><span><a href="#Pantallazos-del-Seguimiento-de-la-actividad-y-uso-de-la-CPU-de-la-Consola-de-Google-Cloud:" data-toc-modified-id="Pantallazos-del-Seguimiento-de-la-actividad-y-uso-de-la-CPU-de-la-Consola-de-Google-Cloud:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Pantallazos del Seguimiento de la actividad y uso de la CPU de la Consola de Google Cloud:</a></span><ul class="toc-item"><li><span><a href="#Pantalla-de-seguimiento-de-la-actividad-y-uso-de-CPU-(comienzo)" data-toc-modified-id="Pantalla-de-seguimiento-de-la-actividad-y-uso-de-CPU-(comienzo)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><strong>Pantalla de seguimiento de la actividad y uso de CPU (comienzo)</strong></a></span></li><li><span><a href="#Pantalla-de-seguimiento-de-la-actividad-y-uso-de-CPU--(inicio-fin)" data-toc-modified-id="Pantalla-de-seguimiento-de-la-actividad-y-uso-de-CPU--(inicio-fin)-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><strong>Pantalla de seguimiento de la actividad y uso de CPU  (inicio-fin)</strong></a></span></li></ul></li></ul></div>

# %% [markdown]
# *******

# %% [markdown]
# Dado que el Máster cursado es un Master de Big Data, se ha decidido ahondar en los conceptos aprendidos del **Cloud de Google** durante el curso y practicar con el Notebook de Jupyter preparado en Python 3 para resolver los algoritmos de Machine Learning aplicados a los diferentes Dataset de datos generados.

# %% [markdown]
# # Pasos realizados en el Cloud de Google
#
# A continuación se detallan los pasos seguidos para ello:
#
# Se accede a la consola del Google Cloud.
#
# Previamente se ha investigado el tipo de máquinas que es posible utilizar en la zona de Bélgica **“europe-west1-c”**, y tras varias pruebas el tipo de máquina que nos permite aprovisionar es  **“n1-highmem-4”**  con 4 vCPUs de 16 GB de memoria.
#
# Desde el Shell, procedemos a crear un nuevo datalab con la zona y tipo de máquina mencionada:
#
# ***datalab create amestfm --machine-type=n1-highmem-4 --zone europe-west1-c***

# %% [markdown]
# ![p1.png](attachment:p1.png)

# %% [markdown]
# Se ha creado ya la instancia a la máquina:

# %% [markdown]
# ![p2.png](attachment:p2.png)

# %% [markdown]
# Comandos del Shell (imagen ampliada):

# %%
from IPython.display import Image
Image(filename='p3.png')

# %% [markdown]
# Se abre el **“Web Preview”** cambiando el puerto al 8081

# %%
from IPython.display import Image
Image(filename='p4.png')

# %% [markdown]
# Para cargar el Notebook de Jupyter que previamente ha sido preparado para ser lanzado posteriormente en el Cloud de Google, se usa la opción **“UPLOAD”**.
#
# Se carga el Notebook, así como los ficheros **“csv”** necesarios, con los datos ya limpios y con la selección de variables más importantes realizada a través del método **“embedded”**, que consta de 59 variables.

# %%
from IPython.display import Image
Image(filename='p5.png')

# %% [markdown]
# Cargados los datos necesarios, se arranca el notebook de Jupyter llamado **“04a_ML_RandomGrid.ipynb”** y se comienza a ejecutar como si se ejecutara en el ordenador personal.

# %%
from IPython.display import Image
Image(filename='p6.png')

# %% [markdown]
# Al importar algunas librerías se ve que no están instaladas en la máquina, y se procede a instalarlas:

# %%
from IPython.display import Image
Image(filename='p7.png')

# %% [markdown]
# Se visualizan a continuación las versiones de las librerías que se utilizan, los sets de datos que se cargan (con 59 variables).
#
# Se genera para cada algoritmo:
# -	500 modelos
# -	5 particiones
# -	20 repeticiones

# %%
from IPython.display import Image
Image(filename='p8.png')

# %% [markdown]
# # Pantallazos durante la ejecución del Notebook

# %% [markdown]
# ## Pantalla con la ejecución de un modelo

# %%
from IPython.display import Image
Image(filename='p9.png')

# %% [markdown]
# ## **Pantalla final tras la ejecución completa del Notebook:**

# %%
from IPython.display import Image
Image(filename='p10.png')

# %% [markdown]
# # Pantallazos del Seguimiento de la actividad y uso de la CPU de la Consola de Google Cloud:

# %% [markdown]
# ## **Pantalla de seguimiento de la actividad y uso de CPU (comienzo)**

# %%
from IPython.display import Image
Image(filename='p11.png')

# %% [markdown]
#                             Ejecución del día 28 de agosto 2019. Hora de comienzo: 20:30

# %% [markdown]
# ## **Pantalla de seguimiento de la actividad y uso de CPU  (inicio-fin)**

# %% [markdown]
# from IPython.display import Image
# Image(filename='p12.png')![p12.png](attachment:p12.png)

# %% [markdown]
#                             Ejecución del día 28 de agosto 2019. Hora de fin: 05:09 horas
